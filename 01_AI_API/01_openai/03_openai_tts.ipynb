# %% [markdown]
# ## <font color=yellow>TEXT를 소리로 바꿔주는 API</font>
#
# `6개의 음성이 제공`
# - 작성된 블로그 게시물 설명
# - 여러 언어로 음성 오디오 생성
# - 스트리밍을 사용하여 실시간 오디오 출력 제공

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI()

# %%
# !mkdir outputs

# %%
tts = client.audio.speech.create(
    model="tts-1",
    voice="nova", # alloy, echo, fable, , nova, and shimmer
    input="안녕하세요 강사 리암입니다."
)

speech_file_path = r"outputs\sample_speech.mp3"
tts.stream_to_file(speech_file_path)
# Out:
# C:\Users\jjsd4\AppData\Local\Temp\ipykernel_11076\1796253843.py:8: DeprecationWarning: Due to a bug, this method doesn't actually stream the response content, `.with_streaming_response.method()` should be used instead
#   tts.stream_to_file(speech_file_path)

# %%
from IPython.display import Audio

# Audio 객체를 생성하고 출력합니다.
audio = Audio(speech_file_path, autoplay=False)
audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
